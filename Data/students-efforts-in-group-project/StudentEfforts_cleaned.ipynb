# %%
import pandas as pd

# %%
data = pd.read_excel("Students-Effort-in-University-Group-Project.xlsx")

# %%
data.head()
# Out:
#   Nationality  How do you evaluate your own contribution  \
# 0     Chinese                                        4.0
# 1     Chinese                                        3.0
# 2     Chinese                                        3.0
# 3     Chinese                                        3.0
# 4     Chinese                                        3.0
#
#    How many AUs was the course  \
# 0                          4.0
# 1                          4.0
# 2                          3.0
# 3                          4.0
# 4                          3.0
#
#    What percentage was the project in your final grade for that course  \
# 0                                                3.0
# 1                                                4.0
# 2                                                3.0
# 3                                                4.0
# 4                                                3.0
#
#    AU*% of grade  Gender  Chinese  German  India  Indonesian   \
# ...

# %%
df = pd.DataFrame(data.columns)

# %%
df
# Out:
#                                                     0
# 0                                         Nationality
# 1           How do you evaluate your own contribution
# 2                         How many AUs was the course
# 3   What percentage was the project in your final ...
# 4                                       AU*% of grade
# 5                                              Gender
# 6                                             Chinese
# 7                                              German
# 8                                               India
# 9                                         Indonesian
# 10                                           Japanese
# 11                                              Korea
# 12                                           Malaysia
# 13                                          Singapura
# 14                                         Vietnamese
# 15                  How long was the project duration
# ...
