# %% [markdown]
# # Part 1: Extract the variable descriptions

# %%
import pandas as pd
import re

# %%
ols_data = pd.read_csv("ols_animal_research_survey_data_2016.csv")

# %%
with open("ols_animal_research_survey_data_2016_ukda_data_dictionary.rtf") as file:  
    data = file.read()

# %%
# data

# %%
question_tuples = re.findall('(Variable\slabel\s=\s\}\{\\\\cf4\s)([\d\w\s\?\.\:\,]*)', data)
question_tuples[0:5]
# Out:
# [('Variable label = }{\\cf4 ', 'Respondent serial'),
#  ('Variable label = }{\\cf4 ',
#   'How well informed do you feel about the use of animals in scientific research in the UK?'),
#  ('Variable label = }{\\cf4 ',
#   'Interested in finding out more about the ongoing work to find alternatives to using animals in research?'),
#  ('Variable label = }{\\cf4 ',
#   'Interested in finding out more about the ongoing work to improve the welfare of animals in scientific research?'),
#  ('Variable label = }{\\cf4 ',
#   'I can accept the use if animals in research as long as it is for medical research purposes and there is no alternative')]

# %%
var_name_tuples = re.findall('(Variable\s=\s\}\{\\\\f2\\\\fs20\\\\cf4\s)([\d\w]*)', data)

# %%
cleaned_data = pd.DataFrame()

# %%
for tuple in enumerate(question_tuples):
    survey_num = 1
    var_name = var_name_tuples[tuple[0]][1]
    question = tuple[1][1]
    cleaned_data = cleaned_data.append([[survey_num, var_name, question]], ignore_index=True)

# %%
cleaned_data.columns = ["Survey_Number", "Var_Name", "Var_Text"]
cleaned_data.head()
# Out:
#    Survey_Number Var_Name                                           Var_Text
# 0              1       ID                                  Respondent serial
# 1              1       Q1  How well informed do you feel about the use of...
# 2              1      Q2a  Interested in finding out more about the ongoi...
# 3              1      Q2b  Interested in finding out more about the ongoi...
# 4              1      Q3a  I can accept the use if animals in research as...

# %%
len(cleaned_data)
# Out:
# 248

# %%
num = 248/3
num
# Out:
# 82.66666666666667

# %%
cleaned_data[82:165]["Survey_Number"] += 1
cleaned_data[165:248]["Survey_Number"] += 2
# Out:
# /Users/bethanybailey/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/bethanybailey/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cleaned_data
# Out:
#      Survey_Number    Var_Name  \
# 0                1          ID
# 1                1          Q1
# 2                1         Q2a
# 3                1         Q2b
# 4                1         Q3a
# 5                1         Q3b
# 6                1         Q3c
# 7                1         Q3d
# 8                1         Q3e
# 9                1         Q3f
# 10               1         Q3g
# 11               1         Q3h
# 12               1         Q3i
# 13               1         Q3j
# 14               1         Q3k
# 15               1         Q3l
# 16               1         Q3m
# 17               1        Q4_1
# 18               1        Q4_2
# 19               1        Q4_3
# 20               1        Q4_4
# 21               1        Q4_5
# 22               1        Q4_6
# 23               1        Q4_7
# 24               1         Q5a
# 25               1         Q5b
# 26               1         Q5c
# 27               1         Q5d
# 28               1         Q5e
# 29               1         Q5f
# ..             ...         ...
# 218              3      Q14_13
# 219              3      Q14_14
# 220              3      Q14_15
# 221              3      Q14_16
# 222              3      Q14_17
# 223              3      Q14_18
# 224              3      Q14_19
# 225              3      Q14_20
# 226              3      Q14_21
# 227              3      Q14_22
# 228              3       AgeB2
# 229              3      sgrade
# 230              3         Soc
# 231              3        Soc2
# 232              3         gor
# 233              3         sex
# 234              3         Eth
# 235              3         Reg
# 236              3         gen
# 237              3      tenure
# 238              3     Empstat
# 239              3        qual
# 240              3     marstat
# 241              3      access
# 242              3      Income
# 243              3  Broadsheet
# 244              3   MidMarket
# 245              3     Tabloid
# 246              3       NoPpr
# 247              3      weight
#
#                                               Var_Text
# 0                                    Respondent serial
# 1    How well informed do you feel about the use of...
# 2    Interested in finding out more about the ongoi...
# 3    Interested in finding out more about the ongoi...
# 4    I can accept the use if animals in research as...
# 5    There needs to be more work done into alternat...
# 6    I can accept the use of animals in scientific ...
# 7    Animals should not be used in any scientific r...
# 8    It does not bother me if animals are used in s...
# 9    The use of animals for medical research should...
# 10   The UK government should ban the use of animal...
# 11   Acceptable to use animals in research to help ...
# 12   Acceptable to use animals in research to help ...
# 13   Acceptable to use animals for all types of res...
# 14   Acceptable to use animals in scientific resear...
# 15   Acceptable to use animals in scientific resear...
# 16   Acceptable to use animals in scientific resear...
# 17   Which of these is true?: The use of animals fo...
# 18   Which of these is true?: Scientists could do m...
# 19   Which of these is true?: Scientific research u...
# 20   Which of these is true?: Scientific research i...
# 21   Which of these is true?: Researchers are worki...
# 22                        Which of these is true?: Don
# 23              Which of these is true?: None of these
# 24   I do not trust the regulatory system around th...
# 25   I trust scientists not to cause unnecessary su...
# 26   I feel that unnecessary duplication of scienti...
# 27   Scientific research involving animals sometime...
# 28   The UK has strict rules on the use of animals ...
# 29   The rules in the UK on scientific research inv...
# ..                                                 ...
# 218  Past 12 months seen or heard animal research i...
# 219  Past 12 months seen or heard animal research i...
# 220  Past 12 months seen or heard animal research i...
# 221  Past 12 months seen or heard animal research i...
# 222  Past 12 months seen or heard animal research i...
# 223  Past 12 months seen or heard animal research i...
# 224  Past 12 months seen or heard animal research i...
# 225  Past 12 months seen or heard animal research i...
# 226  Past 12 months seen or heard animal research i...
# 227  Past 12 months seen or heard animal research i...
# 228                             Respondent age bracket
# 229                            Respondent social grade
# 230                            Respondent social grade
# 231                            Respondent social grade
# 232                Respondent Government Office Region
# 233                                  Respondent gender
# 234                           Respondent ethnic origin
# 235                               Respondent GB region
# 236                              Respondent generation
# 237                                  Respondent tenure
# 238                          Respondent working status
# 239               Respondent highest educational level
# 240                          Respondent marital status
# 241                         Respondent internet access
# 242                          Respondent income bracket
# 243  Respondent regularly reads a daily Broadsheet ...
# 244             Respondent regularly reads a daily Mid
# 245   Respondent regularly reads a daily Tabloid paper
# 246   Respondent does not regularly read a daily paper
# 247                                   Weighting factor
#
# [248 rows x 3 columns]

# %%
def make_csv(survey_num):
    df = cleaned_data[cleaned_data["Survey_Number"] == survey_num]
    df = df.iloc[:, 1:3]
    name = "OLSAnimal_" + str(survey_num) + ".csv"
    print(len(df))
    df.to_csv(path_or_buf=name, index=False)

# %%
make_csv(1)
make_csv(2)
make_csv(3)
# Out:
# 82
# 83
# 83

# %%
cleaned_data.to_csv(path_or_buf="OLSAnimal_cleaned_joined.csv", index=False)

# %% [markdown]
# ## Part 2: Create the survey CSV

# %%
d = {"Survey_Number": [1, 2, 3], 
    "Survey_Name": ["Public Attitudes towards Animal Research 2016-1", "Public Attitudes towards Animal \
    Research 2016-2", "Public Attitudes towards Animal Research 2016-3"], "Num_Participants": [987, 987, 987], \
    "Org_Conduct": ["IPSOS", "IPSOS", "IPSOS"], "Num_Questions": [82, 83, 83], "Data_Link": \
    ["http://bit.ly/2F7fNuv", "http://bit.ly/2F7fNuv", "http://bit.ly/2F7fNuv"], \
    "Documentation_Link": ["http://bit.ly/2CUZWsE", "http://bit.ly/2CUZWsE", "http://bit.ly/2CUZWsE"],\
     "Source_Link": ["http://bit.ly/2CsBSlr", "http://bit.ly/2CsBSlr", "http://bit.ly/2CsBSlr"],\
     "Summary": ["Part 1 of findings of a \
        2016 survey on current public awareness and attitudes towards the use of animals in research. The \
        survey also examines attitudes towards, and trust in, the regulatory system and the people who work \
        with animals in research.",
                 "Part 2 of findings of a \
        2016 survey on current public awareness and attitudes towards the use of animals in research. The \
        survey also examines attitudes towards, and trust in, the regulatory system and the people who work \
        with animals in research.", 
                 "Part 3 of findings of a \
        2016 survey on current public awareness and attitudes towards the use of animals in research. The \
        survey also examines attitudes towards, and trust in, the regulatory system and the people who work \
        with animals in research."]}

# %%
detail = pd.DataFrame(data=d, columns = ["Survey_Number", "Survey_Name", "Num_Participants", \
                      "Org_Conduct", "Num_Questions", "Data_Link", "Documentation_Link", "Source_Link", \
                      "Summary"])

# %%
detail
# Out:
#    Survey_Number                                        Survey_Name  \
# 0              1    Public Attitudes towards Animal Research 2016-1
# 1              2  Public Attitudes towards Animal     Research 2...
# 2              3    Public Attitudes towards Animal Research 2016-3
#
#    Num_Participants Org_Conduct  Num_Questions              Data_Link  \
# 0               987       IPSOS             82  http://bit.ly/2F7fNuv
# 1               987       IPSOS             83  http://bit.ly/2F7fNuv
# 2               987       IPSOS             83  http://bit.ly/2F7fNuv
#
#       Documentation_Link            Source_Link  \
# 0  http://bit.ly/2CUZWsE  http://bit.ly/2CsBSlr
# 1  http://bit.ly/2CUZWsE  http://bit.ly/2CsBSlr
# 2  http://bit.ly/2CUZWsE  http://bit.ly/2CsBSlr
#
#                                              Summary
# 0  Part 1 of findings of a         2016 survey on...
# 1  Part 2 of findings of a         2016 survey on...
# 2  Part 3 of findings of a         2016 survey on...

# %%
detail.to_csv(path_or_buf="OLS_Survey_Detail.csv", index=False)
