# %% [markdown]
# ## Part 1: Extract the questions

# %%
import pandas as pd
import re

# %%
ols_data = pd.read_csv("ols_animal_research_survey_data_2016.csv")

# %%
with open("ols_animal_research_survey_data_2016_ukda_data_dictionary.rtf") as file:  
    data = file.read()

# %%
data
# Out:
# "{\\rtf1\\ansi\\deff0\\deftab1200{\\fonttbl{\\f0\\fswiss MS Sans Serif;}{\\f1\\froman\\fcharset2 Symbol;}{\\f2\\fswiss Arial;}{\\f3\\fswiss\\fprq2 Arial;}{\\f4\\fmodern\\fprq5 Courier New;}{\\f5\\fswiss Arial;}}{\\colortbl;\\red0\\green0\\blue0;\\red255\\green0\\blue0;\\red100\\green100\\blue100;\\red0\\green0\\blue255;\\red10\\green10\\blue160;}\\deflang2057\\pard\\plain\\f2\\fs20\\cf1\\par {\\fs28\\b\\ul UK Data Archive Data Dictionary\\par\\par }{\\b\\f2\\fs20\\cf1\\ File-level information:\\par\\par }{\\f2\\fs20\\cf1 File Name = \t\t\\f2\\fs20\\cf5ols_animal_research_survey_data_2016\\par }{\\f2\\fs20\\cf1 Number of variables = \t\\f2\\fs20\\cf5 248\\par }{\\f2\\fs20\\cf1 Number of cases = \t\\f2\\fs20\\cf5 987\\par\\par\\par }{\\f2\\fs20\\cf1\\b Variable-level information:\\par }{\\cf1\\b\\par Pos. = }{\\f2\\fs20\\cf4 1\t}{\\b\\cf1 Variable = }{\\f2\\fs20\\cf4 ID\t}{\\b\\cf1 Variable label = }{\\cf4 Respondent serial\\par }{\\cf3 This variable is  }{\\cf5\\i numeric}{\\cf3, the SPSS measurement level is }{\\cf5\\i SCALE\\par }{\\cf1 SPSS user missing values = \\cf4 -1.0 \\cf1\\fs16\\ thru \\cf4\\fs20 None\\par \t}{\\cf3\\ul\\fs16 Value label information for ID\\par }{\\cf1\\b\\par Pos. = }{\\f2\\fs20\\cf4 2\t}{\\b\\cf1 Variable = }{\\f2\\fs20\\cf4 Q1\t}{\\b\\cf1 Variable label = }{\\cf4 How well informed do you feel about the use of animals in scientific research in the UK?\\par }{\\cf3 This variable is  }{\\cf5\\i numeric}{\\cf3, the SPSS measurement level is }{\\cf5\\i NOMINAL\\par }{\\cf1 SPSS user missing values = \\cf4 -1.0 \\cf1\\fs16\\ thru \\cf4\\fs20 None\\par \t}{\\cf3\\ul\\fs16 Value label information for Q1\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 1.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Very Well Informed\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 2.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Fairly Well Informed\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 3.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Not Very Well Informed\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 4.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Not At All Informed\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 5.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Don't know\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 6.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 None of these\\par }{\\cf1\\b\\par Pos. = }{\\f2\\fs20\\cf4 3\t}{\\b\\cf1 Variable = }{\\f2\\fs20\\cf4 Q2a\t}{\\b\\cf1 Variable label = }{\\cf4 Interested in finding out more about the ongoing work to find alternatives to using animals in research?\\par }{\\cf3 This variable is  }{\\cf5\\i numeric}{\\cf3, the SPSS measurement level is }{\\cf5\\i NOMINAL\\par }{\\cf1 SPSS user missing values = \\cf4 -1.0 \\cf1\\fs16\\ thru \\cf4\\fs20 None\\par \t}{\\cf3\\ul\\fs16 Value label information for Q2a\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 1.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Very Interested\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 2.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Fairly Interested\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 3.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Not Very Interested\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 4.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Not At All Interested\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 5.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Don't know\\par }{\\cf1\\b\\par Pos. = }{\\f2\\fs20\\cf4 4\t}{\\b\\cf1 Variable = }{\\f2\\fs20\\cf4 Q2b\t}{\\b\\cf1 Variable label = }{\\cf4 Interested in finding out more about the ongoing work to improve the welfare of animals in scientific research?\\par }{\\cf3 This variable is  }{\\cf5\\i numeric}{\\cf3, the SPSS measurement level is }{\\cf5\\i NOMINAL\\par }{\\cf1 SPSS user missing values = \\cf4 -1.0 \\cf1\\fs16\\ thru \\cf4\\fs20 None\\par \t}{\\cf3\\ul\\fs16 Value label information for Q2b\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 1.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Very Interested\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 2.0\t}{\\cf1\\fs16 Label = }{\\cf4\\fs16 Fairly Interested\\par }{\\cf1\\fs16\tValue = }{\\cf4\\fs16 3.0\t}{\\cf1\\fs16  ...

# %%
question_tuples = re.findall('(Variable\slabel\s=\s\}\{\\\\cf4\s)([\d\w\s\?\.\:\,]*)', data)
question_tuples
# Out:
# [('Variable label = }{\\cf4 ', 'Respondent serial'),
#  ('Variable label = }{\\cf4 ',
#   'How well informed do you feel about the use of animals in scientific research in the UK?'),
#  ('Variable label = }{\\cf4 ',
#   'Interested in finding out more about the ongoing work to find alternatives to using animals in research?'),
#  ('Variable label = }{\\cf4 ',
#   'Interested in finding out more about the ongoing work to improve the welfare of animals in scientific research?'),
#  ('Variable label = }{\\cf4 ',
#   'I can accept the use if animals in research as long as it is for medical research purposes and there is no alternative'),
#  ('Variable label = }{\\cf4 ',
#   'There needs to be more work done into alternatives to using animals in scientific research'),
#  ('Variable label = }{\\cf4 ',
#   'I can accept the use of animals in scientific research as long as there is no unnecessary suffering to the animals'),
#  ('Variable label = }{\\cf4 ',
#   'Animals should not be used in any scientific research because of the importance I place on animal welfare'),
#  ('Variable label = }{\\cf4 ',
#   'It does not bother me if animals are used in scientific research'),
#  ('Variable label = }{\\cf4 ',
#   'The use of animals for medical research should only be conducted for life'),
#  ('Variable label = }{\\cf4 ',
#   'The UK government should ban the use of animals for any form of research'),
#  ('Variable label = }{\\cf4 ',
#   'Acceptable to use animals in research to help our understanding of the human body, where there is no alternative'),
#  ('Variable label = }{\\cf4 ',
#   'Acceptable to use animals in research to help our understanding of animal health, where there is no alternative'),
#  ('Variable label = }{\\cf4 ',
#   'Acceptable to use animals for all types of research where there is no  alternative'),
#  ('Variable label = }{\\cf4 ',
#   'Acceptable to use animals in scientific research to test chemicals that could harm people'),
#  ('Variable label = }{\\cf4 ',
#   'Acceptable to use animals in scientific research to test chemicals that could harm pets, farm animals or wildlife'),
#  ('Variable label = }{\\cf4 ',
#   'Acceptable to use animals in scientific research to test chemicals that could harm plants or the environment'),
#  ('Variable label = }{\\cf4 ',
#   'Which of these is true?: The use of animals for medical research purposes is important to human health'),
#  ('Variable label = }{\\cf4 ',
#   'Which of these is true?: Scientists could do more to reduce the suffering of animals used in scientific research'),
#  ('Variable label = }{\\cf4 ',
#   'Which of these is true?: Scientific research using animals is not always carried out to high standards'),
#  ('Variable label = }{\\cf4 ',
#   'Which of these is true?: Scientific research is carried out on animals only  when there is no alternative'),
#  ('Variable label = }{\\cf4 ',
#   'Which of these is true?: Researchers are working to find alternatives to using animals in scientific research'),
#  ('Variable label = }{\\cf4 ', 'Which of these is true?: Don'),
#  ('Variable label = }{\\cf4 ', 'Which of these is true?: None of these'),
#  ('Variable label = }{\\cf4 ',
#   'I do not trust the regulatory system around the use of animals in scientific research'),
#  ('Variable label = }{\\cf4 ',
#   'I trust scientists not to cause unnecessary suffering to the animals used in scientific research '),
#  ('Variable label = }{\\cf4 ',
#   'I feel that unnecessary duplication of scientific research involving animals MIGHT go on'),
#  ('Variable label = }{\\cf4 ',
#   'Scientific research involving animals sometimes goes on without an official licence'),
#  ('Variable label = }{\\cf4 ',
#   'The UK has strict rules on the use of animals in scientific research'),
#  ('Variable label = }{\\cf4 ',
#   'The rules in the UK on scientific research involving animals are well enforced'),
#  ('Variable label = }{\\cf4 ',
#   'I trust the regulators to uncover any misconduct at animal research facilities'),
#  ('Variable label = }{\\cf4 ',
#   'Which are acceptable things for an APO to do?: Ask people to put a sticker '),
#  ('Variable label = }{\\cf4 ',
#   'Which are acceptable things for an APO to do?: Destroy '),
#  ('Variable label = }{\\cf4 ',
#   'Which are acceptable things for an APO to do?: Release animals illegally'),
#  ('Variable label = }{\\cf4 ',
#   'Which are acceptable things for an APO to do?: Hand out leaflets'),
#  ('Variable label = }{\\cf4 ',
#   'Which are acceptable things for an APO to do?: Occupy research facilities illegally'),
#  ('Variable label = }{\\cf4 ',
#   'Which are acceptable things for an APO to do?: None'),
#  ('Variable label = }{\\cf4 ',
#   'Which are acceptable things for an APO to do?: Don'),
#  ('Variable label = }{\\cf4 ',
#   'Which are acceptable things for an APO to do?: Respondent refused'),
#  ('Variable label = }{\\cf4 ',
#   'Which are acceptable things for an APO to do?: Respondent said depends on legality'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Demonstration outside research laboratories'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Demonstration outside homes of people who work in animal research'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Demonstration outside companies which transport research animals'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Demonstration outside companies which supply services to animal research'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: None of these'),
#  ('Variable label = }{\\cf4 ', 'Which is acceptable for an APO to do?: Don'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Respondent refused'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Respondent said depends on legality'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Organise petitions'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Send hate mail or abusive messages to those involved in animal research'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Set up road blocks illegally'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Physical violence against those who carry out scientific research on animals'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Carry out serious crime '),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Organise an ONLINE campaign against people involved in animal research'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Publicise without permission the identity of people carrying out research'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Secretly film the activities in animal research facilities'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Verbally harass people who carry out research on animals'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Write letters to newspapers'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Misrepresent or spin information to support their cause'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: None of these'),
#  ('Variable label = }{\\cf4 ', 'Which is acceptable for an APO to do?: Don'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Respondent refused'),
#  ('Variable label = }{\\cf4 ',
#   'Which is acceptable for an APO to do?: Respondent said depends on legality'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Universities'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Animal protection organisations'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Organisations that support the use of animals in research'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Businesses which carry out the research with animals'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Businesses which sell products developed from the research'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Politicians '),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Government research institutes'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Non'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Environmental organisations'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: The NHS'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: People with a knowledge of the subject'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Farming organisations'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Medical research charities'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Patient groups'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: The media '),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Would check on line '),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Vets who look after the animals used in research'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Other'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: None of these'),
#  ('Variable label = }{\\cf4 ',
#   'Sources of balanced information about use of: Don'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Billboards '),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: General interest magazines'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Specialist magazines '),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Local newspapers'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: National newspapers'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Websites'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Local radio'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: National radio'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: School '),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Social media'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Meetings '),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Telephone information line'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Television'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Do not want more information'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Mail '),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Email'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Other'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: None of these'),
#  ('Variable label = }{\\cf4 ',
#   'Receive information about use of animals in research?: Don'),
#  ('Variable label = }{\\cf4 ', 'How much do you know about the UK Government'),
#  ('Variable label = }{\\cf4 ', 'How much do you know about the UK Government'),
#  ('Variable label = }{\\cf4 ', 'How much do you know about the UK Government'),
#  ('Variable label = }{\\cf4 ',
#   'Did you or did you not know that there is a UK national scientific centre called NC3Rs?'),
#  ('Variable label = }{\\cf4 ',
#   'Are researchers allowed to use animals for: Research to advance our understanding of the human body'),
#  ('Variable label = }{\\cf4 ',
#   'Are researchers allowed to use animals for: Trying to develop new treatments for specific diseases'),
#  ('Variable label = }{\\cf4 ',
#   'Are researchers allowed to use animals for: Research to advance our  understanding of animal health'),
#  ('Variable label = }{\\cf4 ',
#   'Are researchers allowed to use animals for: Testing cosmetics '),
#  ('Variable label = }{\\cf4 ',
#   'Are researchers allowed to use animals for: Developing new methods of medical diagnosis'),
#  ('Variable label = }{\\cf4 ',
#   'Are researchers allowed to use animals for: Safety testing of the ingredients of home cleaning products'),
#  ('Variable label = }{\\cf4 ',
#   'Are researchers allowed to use animals for: Safety testing of chemicals used in industry or farming'),
#  ('Variable label = }{\\cf4 ',
#   'Are researchers allowed to use animals for: None of these'),
#  ('Variable label = }{\\cf4 ',
#   'Are researchers allowed to use animals for: Don'),
#  ('Variable label = }{\\cf4 ',
#   'Should researchers be allowed to use animals for: Research to advance our understanding of the human body'),
#  ('Variable label = }{\\cf4 ',
#   'Should researchers be allowed to use animals for: Trying to develop new treatments for specific diseases'),
#  ('Variable label = }{\\cf4 ',
#   'Should researchers be allowed to use animals for: Research to advance our  understanding of animal health'),
#  ('Variable label = }{\\cf4 ',
#   'Should researchers be allowed to use animals for: Testing cosmetics '),
#  ('Variable label = }{\\cf4 ',
#   'Should researchers be allowed to use animals for: Developing new methods of medical diagnosis'),
#  ('Variable label = }{\\cf4 ',
#   'Should researchers be allowed to use animals for: Safety testing of the ingredients of home cleaning products'),
#  ('Variable label = }{\\cf4 ',
#   'Should researchers be allowed to use animals for: Safety testing of chemicals used in industry or farming'),
#  ('Variable label = }{\\cf4 ',
#   'Should researchers be allowed to use animals for: None of these'),
#  ('Variable label = }{\\cf4 ',
#   'Should researchers be allowed to use animals for: Don'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Fish'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Amphibians e.g. frogs, toads, newts'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Birds'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Mice'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Rats'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Cats'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Dogs'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Pigs'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Small  monkeys such as marmosets'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Large monkeys such as macaques'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Great apes e.g. chimpanzees and gorillas'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Small mammals e.g. rabbits, ferrets'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Larger mammals e.g. sheep, cows'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Insects'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Depends on the reasearch'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Any '),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Snakes '),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Depends on the animal'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Humans'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Animals from their own species'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Other'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: None of these'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Medical research: Don'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Fish'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Amphibians e.g. frogs, toads, newts'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Birds'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Mice'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Rats'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Cats'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Dogs'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Pigs'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Small  monkeys such as marmosets'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Large monkeys such as macaques'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Great apes e.g. chimpanzees and gorillas'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Small mammals e.g. rabbits, ferrets'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Larger mammals e.g. sheep, cows'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Insects'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Depends on the reasearch'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Any '),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Snakes '),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Depends on the animal'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Humans'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Animals from their own species'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Other'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: None of these'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Research into: Don'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Fish'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Amphibians e.g. frogs, toads, newts'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Birds'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Mice'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Rats'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Cats'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Dogs'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Pigs'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Small  monkeys such as marmosets'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Large monkeys such as macaques'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Great apes e.g. chimpanzees and gorillas'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Small mammals e.g. rabbits, ferrets'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Larger mammals e.g. sheep, cows'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Insects'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Depends on the reasearch'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Any '),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Snakes '),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Depends on the animal'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Humans'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Animals from their own species'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Other'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: None of these'),
#  ('Variable label = }{\\cf4 ',
#   'Animals acceptable to use for Environmental: Don'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: They are secretive'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: They are well regulated'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: They have poor animal welfare standards'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: They carry out work essential for human health'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: They stick to  good animal welfare standards'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: They are open about their work'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: They are dishonest about the results of their  work'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: Any positive'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: Any negative'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: Only positive'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: Only negative'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: Don'),
#  ('Variable label = }{\\cf4 ',
#   'Your view of organisations that use animals for research: None of these'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Animal welfare '),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Animals being used for cosmetics research'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Animals being used for research'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Mentions of specific animals'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Charity'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Cancer treatment drug trials '),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Friends '),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Internet '),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Newspaper '),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: News '),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: On TV'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: On social media '),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Protests'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Radio'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: TV advert'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: TV programme '),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Through work'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Through school '),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: No '),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: No answer'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Don'),
#  ('Variable label = }{\\cf4 ',
#   'Past 12 months seen or heard animal research in the UK?: Other'),
#  ('Variable label = }{\\cf4 ', 'Respondent age bracket'),
#  ('Variable label = }{\\cf4 ', 'Respondent social grade'),
#  ('Variable label = }{\\cf4 ', 'Respondent social grade'),
#  ('Variable label = }{\\cf4 ', 'Respondent social grade'),
#  ('Variable label = }{\\cf4 ', 'Respondent Government Office Region'),
#  ('Variable label = }{\\cf4 ', 'Respondent gender'),
#  ('Variable label = }{\\cf4 ', 'Respondent ethnic origin'),
#  ('Variable label = }{\\cf4 ', 'Respondent GB region'),
#  ('Variable label = }{\\cf4 ', 'Respondent generation'),
#  ('Variable label = }{\\cf4 ', 'Respondent tenure'),
#  ('Variable label = }{\\cf4 ', 'Respondent working status'),
#  ('Variable label = }{\\cf4 ', 'Respondent highest educational level'),
#  ('Variable label = }{\\cf4 ', 'Respondent marital status'),
#  ('Variable label = }{\\cf4 ', 'Respondent internet access'),
#  ('Variable label = }{\\cf4 ', 'Respondent income bracket'),
#  ('Variable label = }{\\cf4 ',
#   'Respondent regularly reads a daily Broadsheet paper'),
#  ('Variable label = }{\\cf4 ', 'Respondent regularly reads a daily Mid'),
#  ('Variable label = }{\\cf4 ',
#   'Respondent regularly reads a daily Tabloid paper'),
#  ('Variable label = }{\\cf4 ',
#   'Respondent does not regularly read a daily paper'),
#  ('Variable label = }{\\cf4 ', 'Weighting factor')]

# %%
var_name_tuples = re.findall('(Variable\s=\s\}\{\\\\f2\\\\fs20\\\\cf4\s)([\d\w]*)', data)
# var_name_tuples

# %%
cleaned_data = pd.DataFrame()

# %%
for tuple in enumerate(question_tuples):
    survey_num = 1
    survey_id = "OLSAnimal"
    survey_name = "Public Attitudes towards Animal Research 2016"
    var_name = var_name_tuples[tuple[0]][1]
    question = tuple[1][1]
    link = "http://bit.ly/2oAtsPs"
    cleaned_data = cleaned_data.append([[survey_num, survey_id, survey_name, var_name, question, link]], ignore_index=True)

# %%
cleaned_data.columns = ["Survey_Number","Survey_ID", "Survey_Name", "Var_Name", "Var_Text", "Data_Link"]
cleaned_data.head()
# Out:
#    Survey_Number  Survey_ID                                    Survey_Name  \
# 0              1  OLSAnimal  Public Attitudes towards Animal Research 2016
# 1              1  OLSAnimal  Public Attitudes towards Animal Research 2016
# 2              1  OLSAnimal  Public Attitudes towards Animal Research 2016
# 3              1  OLSAnimal  Public Attitudes towards Animal Research 2016
# 4              1  OLSAnimal  Public Attitudes towards Animal Research 2016
#
#   Var_Name                                           Var_Text  \
# 0       ID                                  Respondent serial
# 1       Q1  How well informed do you feel about the use of...
# 2      Q2a  Interested in finding out more about the ongoi...
# 3      Q2b  Interested in finding out more about the ongoi...
# 4      Q3a  I can accept the use if animals in research as...
#
#                Data_Link
# 0  http://bit.ly/2oAtsPs
# 1  http://bit.ly/2oAtsPs
# 2  http://bit.ly/2oAtsPs
# 3  http://bit.ly/2oAtsPs
# 4  http://bit.ly/2oAtsPs

# %%
len(cleaned_data)
# Out:
# 248

# %%
num = 248/3
num
# Out:
# 82.66666666666667

# %%
ols_data_1 = cleaned_data[0:82]
ols_data_2 = cleaned_data[82:165]
ols_data_3 = cleaned_data[165:248]

# %%
ols_data_2 = ols_data_2.reset_index()
ols_data_3 = ols_data_3.reset_index()
ols_data_2
# Out:
#     index  Survey_Number  Survey_ID  \
# 0      82              1  OLSAnimal
# 1      83              1  OLSAnimal
# 2      84              1  OLSAnimal
# 3      85              1  OLSAnimal
# 4      86              1  OLSAnimal
# 5      87              1  OLSAnimal
# 6      88              1  OLSAnimal
# 7      89              1  OLSAnimal
# 8      90              1  OLSAnimal
# 9      91              1  OLSAnimal
# 10     92              1  OLSAnimal
# 11     93              1  OLSAnimal
# 12     94              1  OLSAnimal
# 13     95              1  OLSAnimal
# 14     96              1  OLSAnimal
# 15     97              1  OLSAnimal
# 16     98              1  OLSAnimal
# 17     99              1  OLSAnimal
# 18    100              1  OLSAnimal
# 19    101              1  OLSAnimal
# 20    102              1  OLSAnimal
# 21    103              1  OLSAnimal
# 22    104              1  OLSAnimal
# 23    105              1  OLSAnimal
# 24    106              1  OLSAnimal
# 25    107              1  OLSAnimal
# 26    108              1  OLSAnimal
# 27    109              1  OLSAnimal
# 28    110              1  OLSAnimal
# 29    111              1  OLSAnimal
# ..    ...            ...        ...
# 53    135              1  OLSAnimal
# 54    136              1  OLSAnimal
# 55    137              1  OLSAnimal
# 56    138              1  OLSAnimal
# 57    139              1  OLSAnimal
# 58    140              1  OLSAnimal
# 59    141              1  OLSAnimal
# 60    142              1  OLSAnimal
# 61    143              1  OLSAnimal
# 62    144              1  OLSAnimal
# 63    145              1  OLSAnimal
# 64    146              1  OLSAnimal
# 65    147              1  OLSAnimal
# 66    148              1  OLSAnimal
# 67    149              1  OLSAnimal
# 68    150              1  OLSAnimal
# 69    151              1  OLSAnimal
# 70    152              1  OLSAnimal
# 71    153              1  OLSAnimal
# 72    154              1  OLSAnimal
# 73    155              1  OLSAnimal
# 74    156              1  OLSAnimal
# 75    157              1  OLSAnimal
# 76    158              1  OLSAnimal
# 77    159              1  OLSAnimal
# 78    160              1  OLSAnimal
# 79    161              1  OLSAnimal
# 80    162              1  OLSAnimal
# 81    163              1  OLSAnimal
# 82    164              1  OLSAnimal
#
#                                       Survey_Name Var_Name  \
# 0   Public Attitudes towards Animal Research 2016    Q7_20
# 1   Public Attitudes towards Animal Research 2016     Q8_1
# 2   Public Attitudes towards Animal Research 2016     Q8_2
# 3   Public Attitudes towards Animal Research 2016     Q8_3
# 4   Public Attitudes towards Animal Research 2016     Q8_4
# 5   Public Attitudes towards Animal Research 2016     Q8_5
# 6   Public Attitudes towards Animal Research 2016     Q8_6
# 7   Public Attitudes towards Animal Research 2016     Q8_7
# 8   Public Attitudes towards Animal Research 2016     Q8_8
# 9   Public Attitudes towards Animal Research 2016     Q8_9
# 10  Public Attitudes towards Animal Research 2016    Q8_10
# 11  Public Attitudes towards Animal Research 2016    Q8_11
# 12  Public Attitudes towards Animal Research 2016    Q8_12
# 13  Public Attitudes towards Animal Research 2016    Q8_13
# 14  Public Attitudes towards Animal Research 2016    Q8_14
# 15  Public Attitudes towards Animal Research 2016    Q8_15
# 16  Public Attitudes towards Animal Research 2016    Q8_16
# 17  Public Attitudes towards Animal Research 2016    Q8_17
# 18  Public Attitudes towards Animal Research 2016    Q8_18
# 19  Public Attitudes towards Animal Research 2016    Q8_19
# 20  Public Attitudes towards Animal Research 2016      Q9a
# 21  Public Attitudes towards Animal Research 2016      Q9b
# 22  Public Attitudes towards Animal Research 2016      Q9c
# 23  Public Attitudes towards Animal Research 2016      Q10
# 24  Public Attitudes towards Animal Research 2016   Q11a_1
# 25  Public Attitudes towards Animal Research 2016   Q11a_2
# 26  Public Attitudes towards Animal Research 2016   Q11a_3
# 27  Public Attitudes towards Animal Research 2016   Q11a_4
# 28  Public Attitudes towards Animal Research 2016   Q11a_5
# 29  Public Attitudes towards Animal Research 2016   Q11a_6
# ..                                            ...      ...
# 53  Public Attitudes towards Animal Research 2016  Q12a_12
# 54  Public Attitudes towards Animal Research 2016  Q12a_13
# 55  Public Attitudes towards Animal Research 2016  Q12a_14
# 56  Public Attitudes towards Animal Research 2016  Q12a_15
# 57  Public Attitudes towards Animal Research 2016  Q12a_16
# 58  Public Attitudes towards Animal Research 2016  Q12a_17
# 59  Public Attitudes towards Animal Research 2016  Q12a_18
# 60  Public Attitudes towards Animal Research 2016  Q12a_19
# 61  Public Attitudes towards Animal Research 2016  Q12a_20
# 62  Public Attitudes towards Animal Research 2016  Q12a_21
# 63  Public Attitudes towards Animal Research 2016  Q12a_22
# 64  Public Attitudes towards Animal Research 2016  Q12a_23
# 65  Public Attitudes towards Animal Research 2016   Q12b_1
# 66  Public Attitudes towards Animal Research 2016   Q12b_2
# 67  Public Attitudes towards Animal Research 2016   Q12b_3
# 68  Public Attitudes towards Animal Research 2016   Q12b_4
# 69  Public Attitudes towards Animal Research 2016   Q12b_5
# 70  Public Attitudes towards Animal Research 2016   Q12b_6
# 71  Public Attitudes towards Animal Research 2016   Q12b_7
# 72  Public Attitudes towards Animal Research 2016   Q12b_8
# 73  Public Attitudes towards Animal Research 2016   Q12b_9
# 74  Public Attitudes towards Animal Research 2016  Q12b_10
# 75  Public Attitudes towards Animal Research 2016  Q12b_11
# 76  Public Attitudes towards Animal Research 2016  Q12b_12
# 77  Public Attitudes towards Animal Research 2016  Q12b_13
# 78  Public Attitudes towards Animal Research 2016  Q12b_14
# 79  Public Attitudes towards Animal Research 2016  Q12b_15
# 80  Public Attitudes towards Animal Research 2016  Q12b_16
# 81  Public Attitudes towards Animal Research 2016  Q12b_17
# 82  Public Attitudes towards Animal Research 2016  Q12b_18
#
#                                              Var_Text              Data_Link
# 0   Sources of balanced information about use of: Don  http://bit.ly/2oAtsPs
# 1   Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 2   Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 3   Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 4   Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 5   Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 6   Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 7   Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 8   Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 9   Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 10  Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 11  Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 12  Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 13  Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 14  Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 15  Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 16  Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 17  Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 18  Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 19  Receive information about use of animals in re...  http://bit.ly/2oAtsPs
# 20       How much do you know about the UK Government  http://bit.ly/2oAtsPs
# 21       How much do you know about the UK Government  http://bit.ly/2oAtsPs
# 22       How much do you know about the UK Government  http://bit.ly/2oAtsPs
# 23  Did you or did you not know that there is a UK...  http://bit.ly/2oAtsPs
# 24  Are researchers allowed to use animals for: Re...  http://bit.ly/2oAtsPs
# 25  Are researchers allowed to use animals for: Tr...  http://bit.ly/2oAtsPs
# 26  Are researchers allowed to use animals for: Re...  http://bit.ly/2oAtsPs
# 27  Are researchers allowed to use animals for: Te...  http://bit.ly/2oAtsPs
# 28  Are researchers allowed to use animals for: De...  http://bit.ly/2oAtsPs
# 29  Are researchers allowed to use animals for: Sa...  http://bit.ly/2oAtsPs
# ..                                                ...                    ...
# 53  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 54  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 55  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 56  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 57  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 58  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 59  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 60  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 61  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 62  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 63  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 64  Animals acceptable to use for Medical research...  http://bit.ly/2oAtsPs
# 65  Animals acceptable to use for Research into: Fish  http://bit.ly/2oAtsPs
# 66  Animals acceptable to use for Research into: A...  http://bit.ly/2oAtsPs
# 67  Animals acceptable to use for Research into: B...  http://bit.ly/2oAtsPs
# 68  Animals acceptable to use for Research into: Mice  http://bit.ly/2oAtsPs
# 69  Animals acceptable to use for Research into: Rats  http://bit.ly/2oAtsPs
# 70  Animals acceptable to use for Research into: Cats  http://bit.ly/2oAtsPs
# 71  Animals acceptable to use for Research into: Dogs  http://bit.ly/2oAtsPs
# 72  Animals acceptable to use for Research into: Pigs  http://bit.ly/2oAtsPs
# 73  Animals acceptable to use for Research into: S...  http://bit.ly/2oAtsPs
# 74  Animals acceptable to use for Research into: L...  http://bit.ly/2oAtsPs
# 75  Animals acceptable to use for Research into: G...  http://bit.ly/2oAtsPs
# 76  Animals acceptable to use for Research into: S...  http://bit.ly/2oAtsPs
# 77  Animals acceptable to use for Research into: L...  http://bit.ly/2oAtsPs
# 78  Animals acceptable to use for Research into: I...  http://bit.ly/2oAtsPs
# 79  Animals acceptable to use for Research into: D...  http://bit.ly/2oAtsPs
# 80  Animals acceptable to use for Research into: Any   http://bit.ly/2oAtsPs
# 81  Animals acceptable to use for Research into: S...  http://bit.ly/2oAtsPs
# 82  Animals acceptable to use for Research into: D...  http://bit.ly/2oAtsPs
#
# [83 rows x 7 columns]

# %%
ols_data_2 = ols_data_2.drop('index', axis=1)
ols_data_3 = ols_data_3.drop('index', axis=1)

# %%
ols_data_1["Survey_ID"] = "OLSAnimal1"
ols_data_1["Survey_Name"] = "Public Attitudes towards Animal Research 2016-1"
ols_data_1.head()
# Out:
# /Users/bethanybailey/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/bethanybailey/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Survey_Number   Survey_ID                                      Survey_Name  \
# 0              1  OLSAnimal1  Public Attitudes towards Animal Research 2016-1
# 1              1  OLSAnimal1  Public Attitudes towards Animal Research 2016-1
# 2              1  OLSAnimal1  Public Attitudes towards Animal Research 2016-1
# 3              1  OLSAnimal1  Public Attitudes towards Animal Research 2016-1
# 4              1  OLSAnimal1  Public Attitudes towards Animal Research 2016-1
#
#   Var_Name                                           Var_Text  \
# 0       ID                                  Respondent serial
# 1       Q1  How well informed do you feel about the use of...
# 2      Q2a  Interested in finding out more about the ongoi...
# 3      Q2b  Interested in finding out more about the ongoi...
# 4      Q3a  I can accept the use if animals in research as...
#
#                Data_Link
# 0  http://bit.ly/2oAtsPs
# 1  http://bit.ly/2oAtsPs
# 2  http://bit.ly/2oAtsPs
# 3  http://bit.ly/2oAtsPs
# 4  http://bit.ly/2oAtsPs

# %%
ols_data_2["Survey_Number"] += 1
ols_data_2["Survey_ID"] = "OLSAnimal2"
ols_data_2["Survey_Name"] = "Public Attitudes towards Animal Research 2016-2"
ols_data_2.head()
# Out:
#    Survey_Number   Survey_ID                                      Survey_Name  \
# 0              2  OLSAnimal2  Public Attitudes towards Animal Research 2016-2
# 1              2  OLSAnimal2  Public Attitudes towards Animal Research 2016-2
# 2              2  OLSAnimal2  Public Attitudes towards Animal Research 2016-2
# 3              2  OLSAnimal2  Public Attitudes towards Animal Research 2016-2
# 4              2  OLSAnimal2  Public Attitudes towards Animal Research 2016-2
#
#   Var_Name                                           Var_Text  \
# 0    Q7_20  Sources of balanced information about use of: Don
# 1     Q8_1  Receive information about use of animals in re...
# 2     Q8_2  Receive information about use of animals in re...
# 3     Q8_3  Receive information about use of animals in re...
# 4     Q8_4  Receive information about use of animals in re...
#
#                Data_Link
# 0  http://bit.ly/2oAtsPs
# 1  http://bit.ly/2oAtsPs
# 2  http://bit.ly/2oAtsPs
# 3  http://bit.ly/2oAtsPs
# 4  http://bit.ly/2oAtsPs

# %%
ols_data_3["Survey_Number"] += 2
ols_data_3["Survey_ID"] = "OLSAnimal3"
ols_data_3["Survey_Name"] = "Public Attitudes towards Animal Research 2016-3"
ols_data_3.head()
# Out:
#    Survey_Number   Survey_ID                                      Survey_Name  \
# 0              3  OLSAnimal3  Public Attitudes towards Animal Research 2016-3
# 1              3  OLSAnimal3  Public Attitudes towards Animal Research 2016-3
# 2              3  OLSAnimal3  Public Attitudes towards Animal Research 2016-3
# 3              3  OLSAnimal3  Public Attitudes towards Animal Research 2016-3
# 4              3  OLSAnimal3  Public Attitudes towards Animal Research 2016-3
#
#   Var_Name                                           Var_Text  \
# 0  Q12b_19  Animals acceptable to use for Research into: H...
# 1  Q12b_20  Animals acceptable to use for Research into: A...
# 2  Q12b_21  Animals acceptable to use for Research into: O...
# 3  Q12b_22  Animals acceptable to use for Research into: N...
# 4  Q12b_23   Animals acceptable to use for Research into: Don
#
#                Data_Link
# 0  http://bit.ly/2oAtsPs
# 1  http://bit.ly/2oAtsPs
# 2  http://bit.ly/2oAtsPs
# 3  http://bit.ly/2oAtsPs
# 4  http://bit.ly/2oAtsPs

# %%
ols_data_1.to_csv(path_or_buf="OLSAnimal_cleaned_1.csv")
ols_data_2.to_csv(path_or_buf="OLSAnimal_cleaned_2.csv")
ols_data_3.to_csv(path_or_buf="OLSAnimal_cleaned_3.csv")

# %% [markdown]
# ## Part 2: Create the survey CSV

# %%
len(ols_data_3)
# Out:
# 83

# %%
d = {"Survey_Number": [1, 2, 3], "Survey_ID": ["OLSAnimal1", "OLSAnimal2", "OLSAnimal3"],
    "Survey_Name": ["Public Attitudes towards Animal Research 2016-1", "Public Attitudes towards Animal \
    Research 2016-2", "Public Attitudes towards Animal Research 2016-3"], "Num_Participants": [987, 987, 987], \
    "Org_Conduct": ["IPSOS", "IPSOS", "IPSOS"], "Num_Questions": [84, 83, 83], "Data_Link": \
    ["http://bit.ly/2oAtsPs", "http://bit.ly/2oAtsPs", "http://bit.ly/2oAtsPs"], \
    "Documentation_Link": ["http://bit.ly/2EYnxyx", "http://bit.ly/2EYnxyx", "http://bit.ly/2EYnxyx"],\
     "Source_Link": ["http://bit.ly/2CsBSlr", "http://bit.ly/2CsBSlr", "http://bit.ly/2CsBSlr"],\
     "Summary": ["Part 1 of findings of a \
        2016 survey on current public awareness and attitudes towards the use of animals in research. The \
        survey also examines attitudes towards, and trust in, the regulatory system and the people who work \
        with animals in research.",
                 "Part 2 of findings of a \
        2016 survey on current public awareness and attitudes towards the use of animals in research. The \
        survey also examines attitudes towards, and trust in, the regulatory system and the people who work \
        with animals in research.", 
                 "Part 3 of findings of a \
        2016 survey on current public awareness and attitudes towards the use of animals in research. The \
        survey also examines attitudes towards, and trust in, the regulatory system and the people who work \
        with animals in research."]}

# %%
detail = pd.DataFrame(data=d, columns = ["Survey_Number", "Survey_ID", "Survey_Name", "Num_Participants", \
                      "Org_Conduct", "Num_Questions", "Data_Link", "Documentation_Link", "Source_Link", \
                      "Summary"])

# %%
detail
# Out:
#    Survey_Number   Survey_ID  \
# 0              1  OLSAnimal1
# 1              2  OLSAnimal2
# 2              3  OLSAnimal3
#
#                                          Survey_Name  Num_Participants  \
# 0    Public Attitudes towards Animal Research 2016-1               987
# 1  Public Attitudes towards Animal     Research 2...               987
# 2    Public Attitudes towards Animal Research 2016-3               987
#
#   Org_Conduct  Num_Questions              Data_Link     Documentation_Link  \
# 0       IPSOS             84  http://bit.ly/2oAtsPs  http://bit.ly/2EYnxyx
# 1       IPSOS             83  http://bit.ly/2oAtsPs  http://bit.ly/2EYnxyx
# 2       IPSOS             83  http://bit.ly/2oAtsPs  http://bit.ly/2EYnxyx
#
#              Source_Link                                            Summary
# 0  http://bit.ly/2CsBSlr  Part 1 of findings of a         2016 survey on...
# 1  http://bit.ly/2CsBSlr  Part 2 of findings of a         2016 survey on...
# 2  http://bit.ly/2CsBSlr  Part 3 of findings of a         2016 survey on...

# %%
detail.to_csv(path_or_buf="OLS_Survey_Detail.csv")
